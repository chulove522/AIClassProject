# %% [markdown]
# #Clean the "movie_metadata.csv" dataset.

# %%
import numpy as np
import pandas as pd

# %%
#Colab資料夾設定方法
#!pip install google.colab #如未安裝取消註解後執行
import os

from google.colab import drive
drive.mount('/content/drive')

##出現提示欄進行授權

os.chdir('/content/drive/My Drive/newmovie/data2/') #切換該目錄
# os.listdir() #確認目錄內容
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
keywords = pd.read_csv('keywords.csv')

# %%
keywords['tmdbId'] = keywords['id']

# %%
keywords.head()
# Out:
#       id                                           keywords  tmdbId
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...     862
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...    8844
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...   15602
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...   31357
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...   11862

# %%
links = pd.read_csv('links.csv')

# %%
links
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 45838   176269  6209470  439050.0
# 45839   176271  2028550  111109.0
# 45840   176273   303758   67758.0
# 45841   176275     8536  227506.0
# 45842   176279  6980792  461257.0
#
# [45843 rows x 3 columns]

# %%
merge = pd.merge(keywords, links, left_on="tmdbId", right_on="tmdbId")

# %%
merge = merge.loc[:,['movieId', 'tmdbId', 'imdbId']]

# %%
merge
# Out:
#        movieId  tmdbId   imdbId
# 0            1     862   114709
# 1            2    8844   113497
# 2            3   15602   113228
# 3            4   31357   114885
# 4            5   11862   113041
# ...        ...     ...      ...
# 46477   176269  439050  6209470
# 46478   176271  111109  2028550
# 46479   176273   67758   303758
# 46480   176275  227506     8536
# 46481   176279  461257  6980792
#
# [46482 rows x 3 columns]

# %%
ratings = pd.read_csv('ratings_small.csv')
# ratings = pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
merge
# Out:
#        movieId  tmdbId   imdbId
# 0            1     862   114709
# 1            2    8844   113497
# 2            3   15602   113228
# 3            4   31357   114885
# 4            5   11862   113041
# ...        ...     ...      ...
# 46477   176269  439050  6209470
# 46478   176271  111109  2028550
# 46479   176273   67758   303758
# 46480   176275  227506     8536
# 46481   176279  461257  6980792
#
# [46482 rows x 3 columns]

# %%
meta_cleaned = pd.read_csv('../newdatas/meta_cleaned.csv')

# %%
meta_cleaned
# Out:
#            id                        title    year  \
# 0         862                    Toy Story  1995.0
# 1        8844                      Jumanji  1995.0
# 2       15602             Grumpier Old Men  1995.0
# 3       31357            Waiting to Exhale  1995.0
# 4       11862  Father of the Bride Part II  1995.0
# ...       ...                          ...     ...
# 42362  289923          The Burkittsville 7  2000.0
# 42363  222848              Caged Heat 3000  1995.0
# 42364   30840                   Robin Hood  1991.0
# 42365  111109          Century of Birthing  2011.0
# 42366   67758                     Betrayal  2003.0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
title = meta_cleaned.loc[:,['id', 'title']]

# %%
# title.id.astype(str)
# title.dtypes
# title.id = pd.to_numeric(title.id, errors='coerce').convert_dtypes() 
# pd.to_numeric(title[id], errors='coerce')

# %%
merge = pd.merge(merge, title, left_on="tmdbId", right_on="id")

# %%
link = merge.loc[:, ['movieId', 'tmdbId', 'imdbId', 'title']]

# %%
link
# Out:
#        movieId  tmdbId   imdbId                        title
# 0            1     862   114709                    Toy Story
# 1            2    8844   113497                      Jumanji
# 2            3   15602   113228             Grumpier Old Men
# 3            4   31357   114885            Waiting to Exhale
# 4            5   11862   113041  Father of the Bride Part II
# ...        ...     ...      ...                          ...
# 43620   176259  289923   252966          The Burkittsville 7
# 43621   176263  222848   112613              Caged Heat 3000
# 43622   176267   30840   102797                   Robin Hood
# 43623   176271  111109  2028550          Century of Birthing
# 43624   176273   67758   303758                     Betrayal
#
# [43625 rows x 4 columns]

# %%
link.to_csv('../newdatas/link.csv',index=True)

# %%
link
# Out:
#        movieId  tmdbId   imdbId                        title
# 0            1     862   114709                    Toy Story
# 1            2    8844   113497                      Jumanji
# 2            3   15602   113228             Grumpier Old Men
# 3            4   31357   114885            Waiting to Exhale
# 4            5   11862   113041  Father of the Bride Part II
# ...        ...     ...      ...                          ...
# 43620   176259  289923   252966          The Burkittsville 7
# 43621   176263  222848   112613              Caged Heat 3000
# 43622   176267   30840   102797                   Robin Hood
# 43623   176271  111109  2028550          Century of Birthing
# 43624   176273   67758   303758                     Betrayal
#
# [43625 rows x 4 columns]
